# %% [markdown]
# Прочитайте базу my_BRENT2019.csv
# Добавьте первые разности и стоимости доллара и евро к рублю(можно добавить их 1-е разности)
# сделайте ее перрасчет (ресемплинг) в представление по неделям.
# Постройте модель предсказания 1-й точки от текущей (h=1).
# Добавьте еще один экзогенный фактор - любой:)
#
# Сравните модель с дополнительным экзогенным фактором и исходную и сделайте вывод о поведении ошибки предсказания ряда в сравнении с прямым прогнозированием.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import SelectFromModel

from sklearn.ensemble import GradientBoostingRegressor

from sklearn.feature_selection import f_regression, mutual_info_regression

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
brent=pd.read_csv('my_BRENT2019.csv')
brent.index=pd.to_datetime(brent['Дата'])
brent.drop('Дата', inplace=True, axis=1)

# %%
brent['price_diff1']=0
brent.iloc[1:,11]=np.array(brent.iloc[1:,0])-np.array(brent.iloc[:-1,0])

# %%
brent.iloc[1:,11]=brent.iloc[1:,0]-brent.iloc[:-1,0]

# %%
brent
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Дата
# 2010-09-01     76.37  2010      9           1        3        244          35
# 2010-09-02     76.89  2010      9           2        3        245          35
# 2010-09-03     76.57  2010      9           3        3        246          35
# 2010-09-04     76.62  2010      9           4        3        247          35
# 2010-09-05     76.63  2010      9           5        3        248          35
# ...              ...   ...    ...         ...      ...        ...         ...
# 2019-08-27     59.59  2019      8          27        3        239          35
# 2019-08-28     59.84  2019      8          28        3        240          35
# 2019-08-29     60.37  2019      8          29        3        241          35
# 2019-08-30     59.19  2019      8          30        3        242          35
# 2019-09-01     58.84  2019      9           1        3        244          35
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday  \
# Дата
# 2010-09-01          2           0                0                0
# 2010-09-02          3           0                0                0
# 2010-09-03          4           0                0                0
# 2010-09-04          5           0                0                0
# 2010-09-05          6           0                1                0
# ...               ...         ...              ...              ...
# 2019-08-27          1           0                0                0
# 2019-08-28          2           0                0                0
# 2019-08-29          3           0                0                0
# 2019-08-30          4           0                0                0
# 2019-09-01          6           0                1                0
#
#             price_diff1
# Дата
# 2010-09-01          0.0
# 2010-09-02          0.0
# 2010-09-03          0.0
# 2010-09-04          0.0
# 2010-09-05          0.0
# ...                 ...
# 2019-08-27          0.0
# 2019-08-28          0.0
# 2019-08-29          0.0
# 2019-08-30          0.0
# 2019-09-01          NaN
#
# [2667 rows x 12 columns]

# %%
rub_doll=pd.read_excel('RC_F01_09_2010_T01_09_2019.xlsx')
rub_doll.index = pd.to_datetime(rub_doll['data'].values).date
rub_doll.drop(['nominal','cdx','data'], axis=1,inplace = True)
rub_doll.rename(columns={'curs':'usd'}, inplace=True)
rub_doll
# Out:
#                 usd
# 2010-09-01  30.8669
# 2010-09-02  30.8001
# 2010-09-03  30.6858
# 2010-09-04  30.6922
# 2010-09-07  30.5771
# ...             ...
# 2019-08-27  65.9735
# 2019-08-28  66.2608
# 2019-08-29  66.4127
# 2019-08-30  66.7471
# 2019-08-31  66.4897
#
# [2228 rows x 1 columns]

# %%
rub_e=pd.read_excel('RC_F01_09_2010_T01_09_2019 (1).xlsx')
rub_e.index = pd.to_datetime(rub_e['data'].values).date
rub_e.drop(['nominal','cdx','data'], axis=1,inplace = True)
rub_e.rename(columns={'curs':'eu'}, inplace=True)
rub_e.head()
# Out:
#                  eu
# 2010-09-01  39.0127
# 2010-09-02  39.1654
# 2010-09-03  39.2901
# 2010-09-04  39.3505
# 2010-09-07  39.4720

# %%
brent=brent.merge(rub_doll, how='left', left_index=True, right_index=True)

# %%
brent=brent.merge(rub_e, how='left', left_index=True, right_index=True)

# %%
bool_series = pd.isnull(brent_w['eu'])
brent_w[bool_series]
# Out:
#               Значение    year  month  dayofmonth  quarter  dayofyear  \
# Дата
# 2011-01-09   94.558000  2011.0    1.0    6.000000      1.0   6.000000
# 2011-10-16         NaN     NaN    NaN         NaN      NaN        NaN
# 2012-01-08  112.974000  2012.0    1.0    5.200000      1.0   5.200000
# 2013-01-06  110.688000  2012.8    3.2    9.200000      1.6  76.200000
# 2015-01-11   50.908333  2015.0    1.0    7.666667      1.0   7.666667
# 2016-01-10   35.982000  2016.0    1.0    6.000000      1.0   6.000000
# 2017-01-08   56.578333  2017.0    1.0    4.666667      1.0   4.666667
# 2018-01-07   67.578000  2018.0    1.0    4.200000      1.0   4.200000
# 2019-01-06   55.916000  2018.8    3.2    9.200000      1.6  76.000000
#
#             weekofyear  dayofweek  is_holiday  is_prev_holiday  \
# Дата
# 2011-01-09         1.0   3.000000    0.000000              0.0
# 2011-10-16         NaN        NaN         NaN              NaN
# 2012-01-08         1.0   3.200000    0.000000              0.0
# 2013-01-06         1.0   3.000000    0.000000              0.2
# 2015-01-11         2.0   2.666667    0.000000              0.0
# 2016-01-10         1.0   2.000000    0.000000              0.0
# 2017-01-08         1.0   2.666667    0.166667              0.0
# 2018-01-07         1.0   3.200000    0.000000              0.0
# 2019-01-06         1.0   3.000000    0.000000              0.2
#
#             is_next_holiday  price_diff1  usd  eu
# Дата
# 2011-01-09         0.000000          0.0  NaN NaN
# 2011-10-16              NaN          NaN  NaN NaN
# 2012-01-08         0.200000          0.0  NaN NaN
# 2013-01-06         0.200000          0.0  NaN NaN
# 2015-01-11         0.000000          0.0  NaN NaN
# 2016-01-10         0.000000          0.0  NaN NaN
# 2017-01-08         0.166667          0.0  NaN NaN
# 2018-01-07         0.200000          0.0  NaN NaN
# 2019-01-06         0.200000          0.0  NaN NaN

# %%
brent_w=brent.resample('W').mean()

# %%
brent_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 470 entries, 2010-09-05 to 2019-09-01
# Freq: W-SUN
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Значение         469 non-null    float64
#  1   year             469 non-null    float64
#  2   month            469 non-null    float64
#  3   dayofmonth       469 non-null    float64
#  4   quarter          469 non-null    float64
#  5   dayofyear        469 non-null    float64
#  6   weekofyear       469 non-null    float64
#  7   dayofweek        469 non-null    float64
#  8   is_holiday       469 non-null    float64
#  9   is_prev_holiday  469 non-null    float64
#  10  is_next_holiday  469 non-null    float64
#  11  price_diff1      469 non-null    float64
#  12  usd              461 non-null    float64
#  13  eu               461 non-null    float64
# dtypes: float64(14)
# memory usage: 55.1 KB

# %%
null = pd.isnull(brent_w['Значение'])
brent_w[null]
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Дата
# 2011-10-16       NaN   NaN    NaN         NaN      NaN        NaN         NaN
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday  \
# Дата
# 2011-10-16        NaN         NaN              NaN              NaN
#
#             price_diff1      usd        eu
# Дата
# 2011-10-16          NaN  32.6037  43.35855

# %%
brent_w.loc['2011-10-16',:]
# Out:
# Значение                NaN
# year                    NaN
# month                   NaN
# dayofmonth              NaN
# quarter                 NaN
# dayofyear               NaN
# weekofyear              NaN
# dayofweek               NaN
# is_holiday              NaN
# is_prev_holiday         NaN
# is_next_holiday         NaN
# price_diff1             NaN
# usd                32.60370
# eu                 43.35855
# Name: 2011-10-16 00:00:00, dtype: float64

# %%
from datetime import timedelta
for i in brent_w[bool_series].index:
    brent_w.loc[i,'usd']=brent_w.loc[i-timedelta(days=7),'usd']
    brent_w.loc[i,'eu']=brent_w.loc[i-timedelta(days=7),'eu']

# %%
brent_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 470 entries, 2010-09-05 to 2019-09-01
# Freq: W-SUN
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Значение         469 non-null    float64
#  1   year             469 non-null    float64
#  2   month            469 non-null    float64
#  3   dayofmonth       469 non-null    float64
#  4   quarter          469 non-null    float64
#  5   dayofyear        469 non-null    float64
#  6   weekofyear       469 non-null    float64
#  7   dayofweek        469 non-null    float64
#  8   is_holiday       469 non-null    float64
#  9   is_prev_holiday  469 non-null    float64
#  10  is_next_holiday  469 non-null    float64
#  11  price_diff1      469 non-null    float64
#  12  usd              470 non-null    float64
#  13  eu               470 non-null    float64
# dtypes: float64(14)
# memory usage: 75.1 KB

# %%
brent_w.dropna(inplace=True)

# %%
brent_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 469 entries, 2010-09-05 to 2019-09-01
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Значение         469 non-null    float64
#  1   year             469 non-null    float64
#  2   month            469 non-null    float64
#  3   dayofmonth       469 non-null    float64
#  4   quarter          469 non-null    float64
#  5   dayofyear        469 non-null    float64
#  6   weekofyear       469 non-null    float64
#  7   dayofweek        469 non-null    float64
#  8   is_holiday       469 non-null    float64
#  9   is_prev_holiday  469 non-null    float64
#  10  is_next_holiday  469 non-null    float64
#  11  price_diff1      469 non-null    float64
#  12  usd              469 non-null    float64
#  13  eu               469 non-null    float64
# dtypes: float64(14)
# memory usage: 55.0 KB

# %%
scl_target=StandardScaler() 

h=1
target = brent_w["Значение"].values[h:].reshape((brent_w.shape[0]-h,1))
y = scl_target.fit_transform(target)
y.shape
# Out:
# (468, 1)

# %%
scl_x=StandardScaler() 

X = brent_w.iloc[:-h,:].values
X = scl_x.fit_transform(X.astype('float64'))
X.shape
# Out:
# (468, 14)

# %%
sfk =SelectKBest(f_regression, k=5)
X_new1 =sfk.fit_transform(X, y.ravel())
X_new1.shape
# Out:
# C:\Users\erbya\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# C:\Users\erbya\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# (468, 5)

# %%
sfp=SelectPercentile(f_regression, percentile=10)
X_new2 = sfp.fit_transform(X, y.ravel())
X_new2.shape
# Out:
# C:\Users\erbya\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# C:\Users\erbya\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# (468, 2)

# %%
gr_model = GradientBoostingRegressor(max_depth=5, random_state=40, n_estimators=100).fit(X, y.ravel())
sfm = SelectFromModel(gr_model,  max_features = 5)

sfm.fit(X, y.ravel())
X_new3 = sfm.transform(X)
X_new3.shape
# Out:
# (468, 1)

# %%
list_param_k =np.where(sfk.get_support())[0]
list_param_p =np.where(sfp.get_support())[0]
list_param_m =np.where(sfm.get_support())[0]

print('Номера признаков k лучших признаков : ',list_param_k)
print('Номера признаков лучших признаков по процентной форме: ',list_param_p)
print('Номера признаков для выбора по модели : ',list_param_m)
# Out:
# Номера признаков k лучших признаков :  [ 0  1  7 12 13]
# Номера признаков лучших признаков по процентной форме:  [ 0 12]
# Номера признаков для выбора по модели :  [0]

# %%
X_new = X[:,[0,1,7,12,13]]

# %%
def split_data( data, split_date ):
    return data.iloc[:split_date,:].copy(), \
           data.iloc[split_date:,:].copy()

# %%
train, test = split_data( brent_w, -50)

plt.figure( figsize=( 15, 7 ))
plt.xlabel('Время')
plt.ylabel('Нефть')
plt.plot(train.index,train.iloc[:,0], label='train data' )
plt.plot(test.index,test.iloc[:,0], label='test data')
plt.title( 'Тестовые и тренировочные данные' )
plt.grid()
plt.legend()
plt.show()

# %%
X_train =X_new[:train.shape[0],:]
y_train =y[:train.shape[0],0]
X_test =X_new[train.shape[0]:,:]
y_test =y[train.shape[0]:,0]

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model_g = GradientBoostingRegressor(max_depth=5, random_state=10, n_estimators=1000)

# %%
model_g.fit( X_train, y_train )
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=1000, random_state=10)

# %%
y_pred_g = model_g.predict(X_train)

# %%
y_test_pred_g = model_g.predict(X_test)

# %%
plt.figure( figsize=( 15, 7 ))


plt.xlabel('Время')
plt.ylabel('BRENT')
plt.plot(y_test_pred_g[:100],'or', label='predict GB data' )
plt.plot(y_test_pred_g[:100],'r' )
plt.plot(y_test[:100], label='test data')
plt.grid()
plt.legend()
plt.show()

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
er_g = mean_absolute_percentage_error(y_true=scl_target.inverse_transform( y_test),y_pred = scl_target.inverse_transform( y_test_pred_g))

print('ошибка градиентного бустинга MAPE :  ', er_g,'%')
# Out:
# ошибка градиентного бустинга MAPE :   3.978149551554275 %

# %%
from sklearn.model_selection import RandomizedSearchCV

def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

param_dist = {"max_depth": [3, 2,1,4,5], 
              "n_estimators":[100,200,300,400,500]}

#  randomized search
n_iter_search = 10

model_gr =GradientBoostingRegressor()

random_search = RandomizedSearchCV(model_gr, param_distributions=param_dist, n_iter=n_iter_search, cv=5, iid=False)

random_search.fit(X_train, y_train)

report(random_search.cv_results_)
# Out:
# Model with rank: 1
# Mean validation score: 0.645 (std: 0.359)
# Parameters: {'n_estimators': 400, 'max_depth': 1}
#
# Model with rank: 2
# Mean validation score: 0.604 (std: 0.407)
# Parameters: {'n_estimators': 100, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.598 (std: 0.420)
# Parameters: {'n_estimators': 200, 'max_depth': 2}
# C:\Users\erbya\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(

# %%
model_g_best = GradientBoostingRegressor(max_depth=1,  n_estimators=400)
model_g_best.fit( X_train, y_train ) 
y_test_pred_g = model_g_best.predict(X_test)

er_g = mean_absolute_percentage_error(y_true=scl_target.inverse_transform( y_test),y_pred = scl_target.inverse_transform( y_test_pred_g))
print('ошибка градиентного бустинга MAPE :  ', er_g,'%')
# Out:
# ошибка градиентного бустинга MAPE :   3.262041535533545 %

# %%
usd_index=pd.read_csv('USD.csv')

# %%
usd_index.index=pd.to_datetime(usd_index['Дата'], dayfirst=True)

# %%
brent
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Дата
# 2010-09-01     76.37  2010      9           1        3        244          35
# 2010-09-02     76.89  2010      9           2        3        245          35
# 2010-09-03     76.57  2010      9           3        3        246          35
# 2010-09-04     76.62  2010      9           4        3        247          35
# 2010-09-05     76.63  2010      9           5        3        248          35
# ...              ...   ...    ...         ...      ...        ...         ...
# 2019-08-27     59.59  2019      8          27        3        239          35
# 2019-08-28     59.84  2019      8          28        3        240          35
# 2019-08-29     60.37  2019      8          29        3        241          35
# 2019-08-30     59.19  2019      8          30        3        242          35
# 2019-09-01     58.84  2019      9           1        3        244          35
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday  \
# Дата
# 2010-09-01          2           0                0                0
# 2010-09-02          3           0                0                0
# 2010-09-03          4           0                0                0
# 2010-09-04          5           0                0                0
# 2010-09-05          6           0                1                0
# ...               ...         ...              ...              ...
# 2019-08-27          1           0                0                0
# 2019-08-28          2           0                0                0
# 2019-08-29          3           0                0                0
# 2019-08-30          4           0                0                0
# 2019-09-01          6           0                1                0
#
#             price_diff1      usd       eu
# Дата
# 2010-09-01          0.0  30.8669  39.0127
# 2010-09-02          0.0  30.8001  39.1654
# 2010-09-03          0.0  30.6858  39.2901
# 2010-09-04          0.0  30.6922  39.3505
# 2010-09-05          0.0      NaN      NaN
# ...                 ...      ...      ...
# 2019-08-27          0.0  65.9735  73.3955
# 2019-08-28          0.0  66.2608  73.6091
# 2019-08-29          0.0  66.4127  73.6583
# 2019-08-30          0.0  66.7471  73.9558
# 2019-09-01          NaN      NaN      NaN
#
# [2667 rows x 14 columns]

# %%
usd_index
# Out:
#                   Дата    Цена   Откр.   Макс.    Мин.   Объём  Изм. %
# Дата
# 2019-10-01  01.10.2019  98,777  99,035  99,305  98,705  23,62K  -0,25%
# 2019-09-30  30.09.2019  99,021  98,770  99,115  98,710  13,81K   0,26%
# 2019-09-27  27.09.2019  98,761  98,805  98,955  98,630  10,39K  -0,00%
# 2019-09-26  26.09.2019  98,765  98,595  98,915  98,450  13,50K   0,11%
# 2019-09-25  25.09.2019  98,659  97,990  98,690  97,965  17,35K   0,75%
# ...                ...     ...     ...     ...     ...     ...     ...
# 2010-09-07  07.09.2010  82,844  82,330  82,940  82,305  31,21K   0,94%
# 2010-09-06  06.09.2010  82,070  82,050  82,160  81,885   5,25K  -0,07%
# 2010-09-03  03.09.2010  82,124  82,485  82,635  82,015  20,91K  -0,46%
# 2010-09-02  02.09.2010  82,501  82,545  82,635  82,305  17,23K  -0,06%
# 2010-09-01  01.09.2010  82,549  83,180  83,265  82,225  23,57K  -0,85%
#
# [2351 rows x 7 columns]

# %%
price_toformat=np.array(usd_index['Цена'])
price_toformat
# Out:
# array(['98,777', '99,021', '98,761', ..., '82,124', '82,501', '82,549'],
#       dtype=object)

# %%
for price in price_toformat:
    new_price=price.replace('')
